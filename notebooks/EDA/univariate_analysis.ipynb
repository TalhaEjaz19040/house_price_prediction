# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house_prices = pd.read_csv('../datasets/house_prices_cleaned.zip')
house_copy = house_prices.copy()
house_copy.drop('Unnamed: 0', axis= 'columns', inplace= True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20096\1314455057.py:1: DtypeWarning: Columns (0: locality) have mixed types. Specify dtype option on import or set low_memory=False.
#   house_prices = pd.read_csv('../datasets/house_prices_cleaned.zip')

# %%
house_copy.describe()
# Out:
#               amount         price   carpet_area      bathroom       balcony  \
# count   67841.000000  6.357500e+04  3.807500e+04  67721.000000  49133.000000
# mean      107.353995  6.669812e+03  3.052560e+03      2.411187      2.087049
# std       687.905116  4.410867e+04  3.349072e+05      0.899991      1.019998
# min         1.000000  0.000000e+00  1.000000e+00      1.000000      1.000000
# 25%        40.000000  3.765000e+03  8.010000e+02      2.000000      1.000000
# 50%        64.000000  5.000000e+03  1.100000e+03      2.000000      2.000000
# 75%       106.000000  7.034000e+03  1.476000e+03      3.000000      3.000000
# max    140030.000000  6.700000e+06  6.534000e+07     11.000000     11.000000
#
#         car_parking    super_area      bedrooms  total_floors
# count  28863.000000  6.375800e+04  67831.000000  65529.000000
# mean       4.024045  3.215058e+03      2.543483      8.521281
# std       34.227493  2.399354e+05      0.831290      6.964287
# min        1.000000  1.000000e+00      1.000000      1.000000
# 25%        1.000000  9.950249e+02      2.000000      4.000000
# 50%        1.000000  1.287895e+03      3.000000      5.000000
# 75%        1.000000  1.730000e+03      3.000000     12.000000
# max      999.000000  4.347288e+07     10.000000    200.000000

# %% [markdown]
# # Univariate Analysis

# %%
def pie(df, explode, colors, edgecolor, textcolor):
    wedges, texts, autotexts = plt.pie(x= df.values, labels= df.index, explode= explode, autopct= '%0.1f%%', colors= colors, shadow= True)
    for wedge in wedges:
        wedge.set_edgecolor(edgecolor)

    for text in texts:
        text.set_fontweight('bold')

    for autotext in autotexts:
        autotext.set_fontweight('bold')
        autotext.set_color(textcolor)

# %%
def uni_box(y, color= 'blue'):
    sns.boxplot(data= house_copy, y= y, color= color, boxprops= {'edgecolor' : 'black'}, medianprops= {'color' : 'black', 'linewidth' : 2})

# %%
def uni_hist(x, color, xlim= False):
    sns.displot(data= house_copy, x= x, kind= 'hist', kde= True, color= color)
    if xlim:
        plt.xlim(house_copy[x].quantile(0.01), house_copy[x].quantile(0.99))

# %%
def bar_h(df, y, threshold, palette, edgecolor, linewidth, ax= None):
    df = df[df['count'] >= threshold]
    sns.barplot(data= df, x= 'count', y= y, hue= y, palette= palette, edgecolor= edgecolor, linewidth= linewidth, ax= ax)

# %%
def bar_v(df, palette, edgecolor, linewidth):
    sns.catplot(x= df.index, y= df.values, kind= 'bar', palette= palette, edgecolor= edgecolor, linewidth= linewidth)

# %%
uni_box('amount')

# %%
uni_hist('amount', 'red')

# %%
house_copy['amount'].skew()
# Out:
# np.float64(154.94097382310096)

# %%
location_count = house_copy['location'].value_counts().reset_index()
bar_h(location_count, 'location', 1000, 'muted', 'black', 1)

# %%
location_count[location_count['count'] >= 1000]['count'].sum() / len(house_copy)
# Out:
# np.float64(0.7194832238385734)

# %%
uni_box('carpet_area')

# %%
uni_hist('carpet_area', 'grey')

# %%
house_copy['carpet_area'].skew()
# Out:
# np.float64(195.0287137011458)

# %%
transaction_count = house_copy['transaction'].value_counts()
bar_v(transaction_count, 'Set2', 'black', 2)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20096\2590324310.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x= df.index, y= df.values, kind= 'bar', palette= palette, edgecolor= edgecolor, linewidth= linewidth)

# %%
transaction_count = transaction_count.reset_index()
transaction_count['percent'] = (transaction_count['count'] / sum(transaction_count['count'])) * 100
transaction_count
# Out:
#     transaction  count    percent
# 0        Resale  50614  74.307778
# 1  New Property  17438  25.601198
# 2         Other     60   0.088088
# 3    Rent/Lease      2   0.002936

# %%
house_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 68192 entries, 0 to 68191
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               68192 non-null  str
#  1   description         65974 non-null  str
#  2   amount              67841 non-null  float64
#  3   price               63575 non-null  float64
#  4   location            68192 non-null  str
#  5   carpet_area         38075 non-null  float64
#  6   floor               65577 non-null  str
#  7   transaction         68114 non-null  str
#  8   furnishing          68192 non-null  str
#  9   facing              41392 non-null  str
#  10  overlooking         38657 non-null  str
#  11  society             29372 non-null  str
#  12  bathroom            67721 non-null  float64
#  13  balcony             49133 non-null  float64
#  14  car_parking         28863 non-null  float64
#  15  ownership           43264 non-null  str
#  16  super_area          63758 non-null  float64
#  17  bedrooms            67831 non-null  float64
#  18  locality            14607 non-null  str
#  19  total_floors        65529 non-null  float64
#  20  car_parking_status  28863 non-null  str
# dtypes: float64(9), str(12)
# memory usage: 10.9 MB

# %%
furnish_count = house_copy['furnishing'].value_counts()
bar_v(furnish_count, 'tab20', 'black', 1.5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20096\2590324310.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x= df.index, y= df.values, kind= 'bar', palette= palette, edgecolor= edgecolor, linewidth= linewidth)

# %%
pie(furnish_count, [0, 0, 0.2], ['#8b1e3f', '#db4c40', '#3c153b'], 'black', 'white')

# %%
facing_count = house_copy['facing'].value_counts().reset_index()
bar_h(facing_count, 'facing', 0, 'husl', 'black', 1.5)

# %%
facing_count['percentage'] = (facing_count['count'] / len(house_copy)) * 100
nulls = (house_copy['facing'].isna().sum()) / len(house_copy) * 100
sums = facing_count['percentage'].sum()

# %%
print(nulls, sums)
mask = facing_count.head(1)
print((mask['percentage'].sum() / sums) * 100)
# Out:
# 39.30079774753637 60.69920225246363
# 45.90258987243912

# %%
facing_count
# Out:
#          facing  count  percentage
# 0          East  19000   27.862506
# 1  North - East   8644   12.675974
# 2         North   5642    8.273698
# 3          West   3301    4.840744
# 4         South   1689    2.476830
# 5  South - East   1256    1.841858
# 6  North - West   1189    1.743606
# 7   South -West    671    0.983986

# %%
house_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 68192 entries, 0 to 68191
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               68192 non-null  str
#  1   description         65974 non-null  str
#  2   amount              67841 non-null  float64
#  3   price               63575 non-null  float64
#  4   location            68192 non-null  str
#  5   carpet_area         38075 non-null  float64
#  6   floor               65577 non-null  str
#  7   transaction         68114 non-null  str
#  8   furnishing          68192 non-null  str
#  9   facing              41392 non-null  str
#  10  overlooking         38657 non-null  str
#  11  society             29372 non-null  str
#  12  bathroom            67721 non-null  float64
#  13  balcony             49133 non-null  float64
#  14  car_parking         28863 non-null  float64
#  15  ownership           43264 non-null  str
#  16  super_area          63758 non-null  float64
#  17  bedrooms            67831 non-null  float64
#  18  locality            14607 non-null  str
#  19  total_floors        65529 non-null  float64
#  20  car_parking_status  28863 non-null  str
# dtypes: float64(9), str(12)
# memory usage: 10.9 MB

# %%
overlooking_count = house_copy['overlooking'].value_counts().reset_index()
overlooking_count
# Out:
#                   overlooking  count
# 0                   Main Road  12249
# 1       Garden/Park,Main Road   9226
# 2                 Garden/Park   8270
# 3  Garden/Park,Main Road,Pool   6593
# 4            Garden/Park,Pool   1750
# 5                        Pool    355
# 6              Main Road,Pool    214

# %%
bar_h(overlooking_count, 'overlooking', 0, 'Paired', 'black', 1.5)

# %%
(house_copy['overlooking'].isna().sum() / len(house_copy)) * 100
# Out:
# np.float64(43.31153214453308)

# %%
(overlooking_count.loc[3, 'count'] / len(house_copy)) * 100
# Out:
# np.float64(9.668289535429375)

# %%
garden_park = (house_copy['overlooking'].str.contains('Garden/Park').sum() / len(house_copy)) * 100
main_road = (house_copy['overlooking'].str.contains('Main Road').sum() / len(house_copy)) * 100
pool = (house_copy['overlooking'].str.contains('Pool').sum() / len(house_copy)) * 100
print(garden_park, main_road, pool)
# Out:
# 37.89154152979822 41.47407320506804 13.06898169873299

# %%
overlooking_df = pd.Series([garden_park, main_road, pool], index= ['Garden/Park', 'Main Road', 'Pool'])
pie(overlooking_df, [0, 0, 0.1], ['#fb8500', '#ffb703', '#023047'], 'black', 'white')

# %%
fig, ax= plt.subplots(figsize= (8,6))
society_count = house_copy['society'].value_counts().reset_index()
bar_h(society_count, 'society', 50, 'husl', 'black', 1, ax)

# %%
print((society_count['count'] >= 50).sum())
len(society_count)
# Out:
# 24
# 10376

# %%
house_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 68192 entries, 0 to 68191
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               68192 non-null  str
#  1   description         65974 non-null  str
#  2   amount              67841 non-null  float64
#  3   price               63575 non-null  float64
#  4   location            68192 non-null  str
#  5   carpet_area         38075 non-null  float64
#  6   floor               65577 non-null  str
#  7   transaction         68114 non-null  str
#  8   furnishing          68192 non-null  str
#  9   facing              41392 non-null  str
#  10  overlooking         38657 non-null  str
#  11  society             29372 non-null  str
#  12  bathroom            67721 non-null  float64
#  13  balcony             49133 non-null  float64
#  14  car_parking         28863 non-null  float64
#  15  ownership           43264 non-null  str
#  16  super_area          63758 non-null  float64
#  17  bedrooms            67831 non-null  float64
#  18  locality            14607 non-null  str
#  19  total_floors        65529 non-null  float64
#  20  car_parking_status  28863 non-null  str
# dtypes: float64(9), str(12)
# memory usage: 10.9 MB

# %%
house_copy['bathroom'].describe()
# Out:
# count    67721.000000
# mean         2.411187
# std          0.899991
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max         11.000000
# Name: bathroom, dtype: float64

# %%
uni_box('bathroom', '#bc6c25')

# %%
bathroom_count = house_copy['bathroom'].value_counts()
bar_v(bathroom_count, 'muted', 'black', 1.5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20096\2590324310.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x= df.index, y= df.values, kind= 'bar', palette= palette, edgecolor= edgecolor, linewidth= linewidth)

# %%
house_copy['balcony'].describe()
# Out:
# count    49133.000000
# mean         2.087049
# std          1.019998
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         11.000000
# Name: balcony, dtype: float64

# %%
uni_box('balcony', '#386641')

# %%
balcony_count = house_copy['balcony'].value_counts()
bar_v(balcony_count, 'husl', 'black', 1.5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20096\2590324310.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x= df.index, y= df.values, kind= 'bar', palette= palette, edgecolor= edgecolor, linewidth= linewidth)

# %%
uni_box('car_parking', '#f15bb5')

# %%
uni_hist('car_parking', '#f15bb5')

# %%
house_copy['car_parking'].skew()
# Out:
# np.float64(16.46047628298504)

# %%
print((house_copy['car_parking'] == 1).sum() / len(house_copy) * 100)
print(house_copy['car_parking'].isna().sum() / len(house_copy) * 100)
# Out:
# 34.204892069450956
# 57.67392069450962

# %%
ownership_count = house_copy['ownership'].value_counts()

# %%
house_copy['ownership'].isna().sum() / len(house_copy) * 100
# Out:
# np.float64(36.55560769591741)

# %%
pie(ownership_count, [0, 0, 0.3, 0], ['#e07a5f', '#3d405b', '#81b29a', '#f2cc8f'], 'black', 'white')

# %%
house_copy['super_area'].describe()
# Out:
# count    6.375800e+04
# mean     3.215058e+03
# std      2.399354e+05
# min      1.000000e+00
# 25%      9.950249e+02
# 50%      1.287895e+03
# 75%      1.730000e+03
# max      4.347288e+07
# Name: super_area, dtype: float64

# %%
uni_hist('super_area', '#a53860', xlim= True)

# %%
house_copy['super_area'].skew()
# Out:
# np.float64(163.60941800346293)

# %%
house_copy['bedrooms'].describe()
# Out:
# count    67831.000000
# mean         2.543483
# std          0.831290
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          3.000000
# max         10.000000
# Name: bedrooms, dtype: float64

# %%
bedroom_count = house_copy['bedrooms'].value_counts()
bar_v(bedroom_count, 'dark', 'black', 1.5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_20096\2590324310.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x= df.index, y= df.values, kind= 'bar', palette= palette, edgecolor= edgecolor, linewidth= linewidth)

# %%
uni_box('bedrooms', '#ffb703')

# %%
house_copy['total_floors'].describe()
# Out:
# count    65529.000000
# mean         8.521281
# std          6.964287
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%         12.000000
# max        200.000000
# Name: total_floors, dtype: float64

# %%
uni_hist('total_floors', '#266907', xlim= True)

# %%
house_copy['car_parking_status'].isna().sum() / len(house_copy) * 100
# Out:
# np.float64(57.67392069450962)

# %%
parking_status_count = house_copy['car_parking_status'].value_counts()
parking_status_count
# Out:
# car_parking_status
# Covered    24814
# Open        4049
# Name: count, dtype: int64

# %%
pie(parking_status_count, [0, 0.1], ['#36ad5e', '#f85a5a'], 'black', 'white')
